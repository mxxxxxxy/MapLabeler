# %% [markdown]
# ##### 解析SVG为config文件
# 若Figma中存在rect元素，将其全部转为Path

# %%
RUN_SILK = False #是否将path的id改为连接的城市名（丝绸之路）

# %%
import xml.etree.ElementTree as ET
from svgelements import Rect, Matrix
# 加载SVG文件
def parse_svg(svg_file):
    # 解析SVG文件
    tree = ET.parse(svg_file)
    root = tree.getroot()
    # 命名空间 (一般SVG文件会包含默认的命名空间)
    # 根据具体的SVG文件，可能需要调整命名空间前缀
    namespace = {'svg': 'http://www.w3.org/2000/svg'}
    
    # 查找所有 <g> 元素
    root_g = root.find('./svg:g', namespace)  # 使用命名空间避免解析问题
    g_elements = root_g.findall('./svg:g', namespace)  # 使用命名空间避免解析问题
    
    layers = {}
    # 遍历 <g> 元素并提取属性 （图层）
    for g in g_elements:
        # print(f"Found <g> element with attributes: {g.attrib}")
        elements = []
        # 如果需要进一步提取 <g> （图层） 内子元素及其信息
        for child in g:
            # childTag = child.tag.replace('{http://www.w3.org/2000/svg}','')
            text = child.find('.//svg:text', namespace)
            rect = child.find('.//svg:rect', namespace)
            path = child.find('.//svg:path', namespace)
            circle = child.find('.//svg:circle', namespace)
            textData = []
            if text is not None:
                text_attr = text.attrib
                # print(text_attr['transform'])
                transform = text_attr.get('transform', '')
                font_size = text_attr.get('font-size', '')
                for tspan in text:
                    tspan_attr = tspan.attrib
                    textData.append({
                        "pos": [tspan_attr['x'], tspan_attr['y']],
                        "text": tspan.text,
                        "font-size": font_size,
                        "transform": transform
                    })
            if rect is not None:
                rect_attr = rect.attrib
                rect_tranform = rect_attr.get("transform", "")
                if rect_tranform:
                    d = Rect(rect_attr['x'], rect_attr['y'], rect_attr['width'], rect_attr['height'], transform=rect_tranform).d()
                else:
                    d = Rect(rect_attr['x'], rect_attr['y'], rect_attr['width'], rect_attr['height']).d()
                del rect_attr['x']
                del rect_attr['y']
                del rect_attr['width']
                del rect_attr['height']
                rect_attr['d'] = d
                elements.append({**rect_attr, 'tag': 'path', 'text': textData})
                continue
            if path is not None:
                elements.append({**path.attrib, 'tag': 'path', 'text': textData})
                if textData:
                    textName = textData[0].get('text')
                    if path.attrib['id'].startswith('Vector') and textName is not None:
                        elements[-1]['id'] = textName
            if circle is not None:
                elements.append({**circle.attrib, 'tag': 'circle', 'text': textData})
            if g.attrib['id'] == '城市边界CHGIS':
                elements[-1]['id'] += 'CHGIS'
            if len(textData) > 0:
                elements[-1]['id'] = textData[0]['text']
        layers[g.attrib['id']] = elements
    return layers

# 示例SVG文件路径
svg_file = './silk.svg'  # 替换为你的SVG文件路径
layers = parse_svg(svg_file)

# %%
print(layers)
# Out:
# {'路径': [{'id': 'Vector 12', 'd': 'M2069 609C2035.37 613.125 2020.62 612.67 2007.5 603C1993.34 587.66 1979 581 1970 567C1924.48 573.976 1791 726 1727 718.5C1594.04 715.137 1617.09 754.05 1614 808C1600.66 812.921 1590.27 813.57 1568 812C1550.15 806.696 1539.33 800.903 1519 787C1478.74 760.885 1460.5 747.779 1448 731.5C1425 687.776 1411.62 663.497 1384 622C1375.82 616.368 1369.56 614.857 1354 616.5C
 'stroke': '#FD2B0D', 'stroke-width': '3.1', 'tag': 'path', 'text': []}, {'id': 'Vector 14', 'd': 'M1607 525C1684 527.5 1713 554 1803 561', 'stroke': '#FD2B0D', 'stroke-width': '3.1', 'tag': 'path', 'text': []},  ...

# %% [markdown]
# ##### 丝绸之路
# 分解path的d属性为一小段

# %%
import re
import math
from svg.path import parse_path, Move, Line, CubicBezier, QuadraticBezier, Arc, Close

# --- 从之前代码中保留和改进的辅助函数 ---
def format_coordinate(num):
    """
    辅助函数，用于格式化坐标值。
    将浮点数整数（如 205.0）转换为整数字符串（"205"）。
    对于其他浮点数，保留适当的精度并去除末尾多余的0和小数点。
    """
    if isinstance(num, complex):
        return f"{format_coordinate(num.real)} {format_coordinate(num.imag)}"
    if isinstance(num, float) and num.is_integer():
        return str(int(num))
    formatted_num = f"{num:.10g}" 
    if '.' in formatted_num:
        formatted_num = formatted_num.rstrip('0').rstrip('.')
    return formatted_num

def point_to_str(p):
    """将一个复数点 (complex number) 转换为 'x y' 格式的字符串。"""
    if p is None:
        return "0 0" 
    return f"{format_coordinate(p.real)} {format_coordinate(p.imag)}"

def get_command_params_str(segment_obj):
    """
    根据路径段对象，生成其命令和参数部分的字符串。
    """
    if isinstance(segment_obj, Line):
        return f"L {point_to_str(segment_obj.end)}"
    elif isinstance(segment_obj, CubicBezier):
        return f"C {point_to_str(segment_obj.control1)} {point_to_str(segment_obj.control2)} {point_to_str(segment_obj.end)}"
    elif isinstance(segment_obj, QuadraticBezier):
        return f"Q {point_to_str(segment_obj.control)} {point_to_str(segment_obj.end)}"
    elif isinstance(segment_obj, Arc):
        return (f"A {format_coordinate(segment_obj.radius.real)} {format_coordinate(segment_obj.radius.imag)} "
                f"{format_coordinate(segment_obj.rotation)} {int(segment_obj.arc)} {int(segment_obj.sweep)} "
                f"{point_to_str(segment_obj.end)}")
    elif isinstance(segment_obj, Close):
        return "Z"
    return ""

def preprocess_d_attribute(d_attr):
    """
    预处理d属性字符串，尝试修复常见语法问题，
    例如数字后紧跟命令字母（如 "0.5M" 修复为 "0.5 M"）。
    """
    # 正则表达式查找： (数字) (命令字母) -> (数字) (空格) (命令字母)
    corrected_d = re.sub(r'(\d(?:\.\d*)?)([MmZzLlHhVvCcSsQqTtAa])', r'\1 \2', d_attr)
    return corrected_d

def extract_start_end_points_from_d(d_str):
    """
    从SVG path的d属性中获取起点和终点坐标
    :param d_str: SVG path的d属性字符串
    :return: (起点坐标, 终点坐标)，例如 ((x1, y1), (x2, y2))
    """
    path_obj = parse_path(d_str)
    if not path_obj or len(path_obj) == 0:
        return None, None
    start_pt = (path_obj[0].start.real, path_obj[0].start.imag)
    end_pt = (path_obj[-1].end.real, path_obj[-1].end.imag)
    return start_pt, end_pt

# --- 用于匹配城市的函数 ---
def euclidean_distance(p1, p2):
    """计算两点 p1(x1,y1) 和 p2(x2,y2) 之间的欧几里得距离。"""
    return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def find_closest_city(point, cities_map_data, tolerance=float('inf')):
    """
    从城市列表中找到离给定点最近的城市。
    point: (x, y) 元组
    cities_map_data: 城市数据列表，格式为 [ ((x,y), "城市名"), ... ]
    tolerance: 只有当距离小于此值时才认为匹配成功
    返回: (("城市名", (cx, cy)), 距离) 或 ((None, None), float('inf'))
    """
    if not cities_map_data:
        return ((None, None), float('inf'))

    closest_city_info = (None, None)
    min_distance = float('inf')

    for city_coord, city_name in cities_map_data:
        # 确保 city_coord 是 (x,y) 元组
        if not (isinstance(city_coord, (tuple, list)) and len(city_coord) == 2):
            print(f"警告: 城市数据 '{city_name}' 的坐标格式不正确: {city_coord}。已跳过。")
            continue
        try:
            # 确保坐标是数字
            coord_x = float(city_coord[0])
            coord_y = float(city_coord[1])
        except ValueError:
            print(f"警告: 城市数据 '{city_name}' 的坐标值无法转换为数字: {city_coord}。已跳过。")
            continue

        distance = euclidean_distance(point, (coord_x, coord_y))
        if distance < min_distance:
            min_distance = distance
            closest_city_info = (city_name, (coord_x, coord_y))
            
    if min_distance <= tolerance:
        return closest_city_info, min_distance
    else:
        return ((None, None), min_distance) # 返回None表示没有在容差范围内找到城市


if RUN_SILK:
    citys = layers['城市']
    cityData = []
    for city in citys:
        cityData.append(((float(city['cx']), float(city['cy'])), city['id']))

# %% [markdown]
# 处理path的id为 [start_city]-[end_city] e.g., 天水-兰州

# %%
def process_d_attr(d_attr):
    # path_segments_with_endpoints = split_svg_path_into_segment_data(d_attr)
    # print(path_segments_with_endpoints)

    # print("路径段及其连接的城市：")
    # print("=" * 30)

    (start_point, end_point) = extract_start_end_points_from_d(d_attr)
    
    # print(f"  SVG 起点: ({format_coordinate(start_point[0])}, {format_coordinate(start_point[1])})")
    # print(f"  SVG 终点: ({format_coordinate(end_point[0])}, {format_coordinate(end_point[1])})")

    # 匹配起点城市 (可以设置一个较小的容差，比如1个像素单位，如果需要精确匹配)
    # 如果你的城市坐标就是从SVG路径命令的端点精确提取的，容差可以设为很小的值（例如0.1）
    # 如果城市坐标是手动标记的，可能需要更大的容差
    match_tolerance = float('inf') # 匹配容差：例如，距离小于1个单位才认为匹配
    
    (start_city_info, start_dist) = find_closest_city(start_point, cityData, tolerance=match_tolerance)
    (end_city_info, end_dist) = find_closest_city(end_point, cityData, tolerance=match_tolerance)

    start_city_name, start_city_coord = start_city_info
    end_city_name, end_city_coord = end_city_info
    return start_city_name, end_city_name
    # if start_city_name:
    #     print(f"  连接起点城市: {start_city_name} @ ({format_coordinate(start_city_coord[0])}, {format_coordinate(start_city_coord[1])}) (距离: {start_dist:.2f})")
    # else:
    #     print(f"  连接起点城市: 未在容差 {match_tolerance} 内匹配到城市 (最近距离: {start_dist:.2f})")
    #     # 如果需要显示最近的城市，即使它超出容差：
    #     # (fallback_start_city_info, fallback_start_dist) = find_closest_city(start_point, cityData)
    #     # if fallback_start_city_info[0]:
    #     #     print(f"    (最接近但超出容差: {fallback_start_city_info[0]} @ {fallback_start_city_info[1]}, 距离: {fallback_start_dist:.2f})")


    # if end_city_name:
    #     print(f"  连接终点城市: {end_city_name} @ ({format_coordinate(end_city_coord[0])}, {format_coordinate(end_city_coord[1])}) (距离: {end_dist:.2f})")
    # else:
    #     print(f"  连接终点城市: 未在容差 {match_tolerance} 内匹配到城市 (最近距离: {end_dist:.2f})")
    #     (fallback_end_city_info, fallback_end_dist) = find_closest_city(end_point, cityData)
    #     if fallback_end_city_info[0]:
    #         print(f"    (最接近但超出容差: {fallback_end_city_info[0]} @ {fallback_end_city_info[1]}, 距离: {fallback_end_dist:.2f})")



#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 34 no',
#    'd': 'M221 327C232.889 315.338 239.475 309.223 251 299.5C279 309.5 291.419 319.765 306.5 337C313.5 345 336.5 377 367 410.5C391.625 438.88 411.592 466.049 410.5 466.5C408.17 492.792 414.58 504.776 442 520.5',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 33',
#    'd': 'M442.5 520.5C380 495.5 412.5 405 494 412.5C512.603 429.972 522.823 437.349 540.5 444.5',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 35 no',
#    'd': 'M1177 531.5C1133 515 1116 504 1059.5 476.5C1022.5 466 1035.5 506 1035.5 506C1037 560.5 1035.5 563 972 577',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 36 no',
#    'd': 'M663.5 503.5C676.911 476.3 693.774 469.081 737 465C792.596 459.751 823.628 465.31 879 496C897 509.5 931.94 547.679 955.5 569',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 37',
#    'd': 'M837 633C806.07 756.061 787.628 811.397 750 893',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 38',
#    'd': 'M837 633C854.087 663.433 867.773 677.807 902 697',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 39 no',
#    'd': 'M1246.5 674C1298 684 1334.47 712.349 1338.5 734C1344.03 763.709 1370 745.5 1373.5 730.5C1378.5 687 1350 680 1384 622.5',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 40',
#    'd': 'M1917 422C1915.47 455.111 1913.04 472.412 1904 499.5',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 41',
#    'd': 'M727.5 269.5C786 296.5 856.5 299.5 909.5 293.5',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 42',
#    'd': 'M910 293.5C960.12 282.168 982.816 274.648 1000.5 274C1058.8 271.865 1113 280 1147.5 280C1161.5 281.5 1161 284.5 1168.5 287',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 43 no',
#    'd': 'M1168 286.5C1260.2 274.297 1333.5 282.5 1443.5 282.5C1491 279.5 1599.5 258.5 1669.5 258.5C1778.5 258.5 1885.5 276.5 1973.5 298',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 44',
#    'd': 'M1974 299C2008.28 207.469 2024.41 174.66 2048 147.5',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 51 no',
#    'd': 'M1974 298C1856.1 270.202 1789.62 259.74 1669.5 259C1659.5 235.5 1637.11 215.925 1567 200.5L1495.5 164C1471.1 148.487 1456.5 143 1422 144L1321 144.5C1221.07 150.859 1174 165.349 1103 207C1059.4 231.944 1033.64 240.955 982 235.5C940.073 225.873 918.85 242.422 883.5 296C823.253 297.661 789.206 292.184 728 269.5',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 45',
#    'd': 'M1974 298.5C1945 357 1925.5 405 1917 422',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 46',
#    'd': 'M1974 298.5C2017.5 437.5 1982 408.5 2016 509',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 47',
#    'd': 'M1974 298.5C2062.5 348 2033.5 454.5 2152 468.5',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 48',
#    'd': 'M1168 287C1197.5 306.5 1271.5 364.5 1345.5 401',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 49',
#    'd': 'M1168 287C1153.72 278.052 1143 280 1101.5 278C1059 338.5 1111.5 401.5 1152 432',
#    'stroke': '#F5DE60',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 50',
#    'd': 'M1412 396C1441.41 433.636 1458.24 445.873 1492 454.5L1522 442.5',
#    'stroke': '#FD2B0D',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 52',
#    'd': 'M2309.5 533.5L2379 502',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 53',
#    'd': 'M2310 533.5C2339.5 517.5 2366 545.5 2317.5 567.5C2277.37 591.023 2294 618 2310 639.5C2329.82 675.028 2332.79 689.648 2307 695.5',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 54 no',
#    'd': 'M2307.5 696C2370.18 679.865 2403.14 662.204 2461 627',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector

#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 80',
#    'd': 'M2277 1023C2270.48 1027.62 2268.95 1032.68 2269 1043.5C2267 1094 2253.5 1106 2233 1130C2193.56 1174.19 2182 1211.5 2177 1225',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 81',
#    'd': 'M2177 1224C2122.5 1191.5 2062.82 1154.43 2072.5 1101C2079.5 1093 2097 1069.5 2077 1047.5',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 82',
#    'd': 'M1998.5 1360.5C2010.18 1366.68 2013.87 1371.11 2017.5 1380C2024 1401 2027 1413.5 2031.5 1430',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 83',
#    'd': 'M1998.5 1360.5C1993.21 1354.63 1992.95 1348.8 1994.5 1336.5C1997 1328 1997.53 1317.53 1991.5 1309C1985.63 1311.1 1981.19 1310.11 1971.5 1305',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 84 no',
#    'd': 'M1998.5 1360.5C1993.21 1354.63 1992.95 1348.8 1994.5 1336.5C1997 1328 1997.53 1317.53 1991.5 1309C1999.5 1304.5 2001.5 1287.5 2003 1258C2009.57 1214.92 2010.43 1191.42 2031.5 1145C2048.59 1128.38 2057.44 1118.81 2072.5 1101.5C2087.3 1079.47 2092.9 1067.31 2077 1047.5',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 85',
#    'd': 'M612.5 724.5C655.115 802.016 687.5 867.5 736 901',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 86',
#    'd': 'M736 901.5C764.5 1008 819 1104 845 1068',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 68 no_2',
#    'd': 'M1736 878C1726.5 898 1680.5 917 1620.5 950C1553.19 987.018 1522 1065.5 1511.5 1120C1510.09 1130.84 1509.95 1134.67 1510 1140.5',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []},
#   {'id': 'Vector 88',
#    'd': 'M2032.5 1431.5C2081.8 1426.14 2114.5 1431.5 2140.5 1451.5',
#    'stroke': '#6B84BF',
#    'stroke-width': '3.1',
#    'tag': 'path',
#    'text': []}],
#  '城市': [{'id': '雅典',
#    'cx': '441.843',
#    'cy': '520.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['424', '541.109'],
#      'text': '雅典',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '伊斯坦布尔',
#    'cx': '540.843',
#    'cy': '444.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['528', '437.109'],
#      'text': '伊斯坦布尔',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '安卡拉',
#    'cx': '614.843',
#    'cy': '471.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['569', '492.109'],
#      'text': '安卡拉',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '开赛利',
#    'cx': '662.843',
#    'cy': '501.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['615', '521.109'],
#      'text': '开赛利',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '巴统',
#    'cx': '786.843',
#    'cy': '430.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['750', '434.498'],
#      'text': '巴统',
#      'font-size': '15.12',
#      'transform': ''}]},
#   {'id': '塔甘罗格',
#    'cx': '727.843',
#    'cy': '268.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['698', '261.498'],
#      'text': '塔甘罗格',
#      'font-size': '15.12',
#      'transform': ''}]},
#   {'id': '萨莱',
#    'cx': '909.843',
#    'cy': '292.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['894', '313.595'],
#      'text': '萨莱',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '阿拉尔克斯',
#    'cx': '1167.84',
#    'cy': '286.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1132', '274.176'],
#      'text': '阿拉尔克斯',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '若羌',
#    'cx': '1671.84',
#    'cy': '498.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1633', '497.176'],
#      'text': '若羌',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '且末',
#    'cx': '1606.84',
#    'cy': '523.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1596', '544.176'],
#      'text': '且末',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '玉门关',
#    'cx': '1766.84',
#    'cy': '457.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1727', '476.176'],
#      'text': '玉门关',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '敦煌',
#    'cx': '1793.84',
#    'cy': '471.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1780', '461.176'],
#      'text': '敦煌',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '瓜州',
#    'cx': '1817.84',
#    'cy': '463.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1821', '459.176'],
#      'text': '瓜州',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '酒泉',
#    'cx': '1874.84',
#    'cy': '485.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1865', '477.176'],
#      'text': '酒泉',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '哈拉和林',
#    'cx': '1973.84',
#    'cy': '297.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1985', '300.176'],
#      'text': '哈拉和林',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '乌兰乌德',
#    'cx': '2047.84',
#    'cy': '146.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2055', '153.176'],
#      'text': '乌兰乌德',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '张掖',
#    'cx': '1903.84',
#    'cy': '498.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1879', '518.176'],
#      'text': '张掖',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '格尔木',
#    'cx': '1802.84',
#    'cy': '559.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1779', '580.176'],
#      'text': '格尔木',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '都兰',
#    'cx': '1860.84',
#    'cy': '562.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1845', '581.176'],
#      'text': '都兰',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '共和',
#    'cx': '1912.84',
#    'cy': '562.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1897', '582.176'],
#      'text': '共和',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '武威',
#    'cx': '1944.84',
#    'cy': '520.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1937', '514.176'],
#      'text': '武威',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '哈密',
#    'cx': '1777.84',
#    'cy': '403.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1771', '396.176'],
#      'text': '哈密',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '额齐纳旗',
#    'cx': '1916.84',
#    'cy': '421.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1860', '426.085'],
#      'text': '额齐纳旗',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '银川',
#    'cx': '2015.84',
#    'cy': '508.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2020', '505.085'],
#      'text': '银川',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '兰州',
#    'cx': '1969.84',
#    'cy': '566.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1969', '562.085'],
#      'text': '兰州',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '固原',
#    'cx': '2023.84',
#    'cy': '565.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2000', '584.085'],
#      'text': '固原',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '天水',
#    'cx': '2007.84',
#    'cy': '602.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1982', '622.085'],
#      'text': '天水',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '西安',
#    'cx': '2068.5',
#    'cy': '608.5',
#    'r': '6.5',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2052', '629.085'],
#      'text': '西安',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '洛阳',
#    'cx': '2137.84',
#    'cy': '598.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2113', '593.085'],
#      'text': '洛阳',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '正蓝旗',
#    'cx': '2200.84',
#    'cy': '414.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2179', '407.085'],
#      'text': '正蓝旗',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '北京',
#    'cx': '2211.84',
#    'cy': '472.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2216', '487.085'],
#      'text': '北京',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '平壤',
#    'cx': '2390.84',
#    'cy': '495.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2392', '488.085'],
#      'text': '平壤',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '宁波',
#    'cx': '2309.84',
#    'cy': '710.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2285', '730.085'],
#      'text': '宁波',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '杭州',
#    'cx': '2283.84',
#    'cy': '702.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2268', '693.085'],
#      'text': '杭州',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '庆州',
#    'cx': '2457.84',
#    'cy': '571.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2431', '591.085'],
#      'text': '庆州',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '首尔',
#    'cx': '2414.84',
#    'cy': '532.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2422', '532.085'],
#      'text': '首尔',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '烟台',
#    'cx': '2309.84',
#    'cy': '533.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2281', '525.085'],
#      'text': '烟台',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '辽阳',
#    'cx': '2340.84',
#    'cy': '437.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2330', '428.085'],
#      'text': '辽阳',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '朝阳',
#    'cx': '2287.84',
#    'cy': '430.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2275', '422.085'],
#      'text': '朝阳',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '大同',
#    'cx': '2151.84',
#    'cy': '467.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2152', '488.085'],
#      'text': '大同',
#      'font-size': '15.36',
#      'transform': ''}]},
#   {'id': '乌尔根奇',
#    'cx': '1151.84',
#    'cy': '431.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1125', '453.176'],
#      'text': '乌尔根奇',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '巴库',
#    'cx': '941.843',
#    'cy': '459.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['926', '478.176'],
#      'text': '巴库',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '安克条',
#    'cx': '678.843',
#    'cy': '560.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['626', '567.109'],
#      'text': '安克条',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '阿顿颇',
#    'cx': '697.843',
#    'cy': '562.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['687', '557.109'],
#      'text': '阿顿颇',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '巴尔米拉',
#    'cx': '707.843',
#    'cy': '587.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['712', '583.109'],
#      'text': '巴尔米拉',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '贝鲁特',
#    'cx': '662.843',
#    'cy': '617.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['610', '625.109'],
#      'text': '贝鲁特',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '大马士革',
#    'cx': '682.843',
#    'cy': '625.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['668', '644.109'],
#      'text': '大马士革',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '佩特拉',
#    'cx': '662.843',
#    'cy': '690.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['668', '697.109'],
#      'text': '佩特拉',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '亚历山大',
#    'cx': '558.843',
#    'cy': '679.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['524', '673.109'],
#      'text': '亚历山大',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '开罗',
#    'cx': '582.843',
#    'cy': '705.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['566', '726.109'],
#      'text': '开罗',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '麦加',
#    'cx': '749.843',
#    'cy': '892.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['752', '911.109'],
#      'text': '麦加',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '亚丁',
#    'cx': '846.843',
#    'cy': '1063.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['834', '1056.07'],
#      'text': '亚丁',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '佐法尔',
#    'cx': '1025.84',
#    'cy': '990.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['997', '976.07'],
#      'text': '佐法尔',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '卡拉奇',
#    'cx': '1267.84',
#    'cy': '819.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1265', '824.07'],
#      'text': '卡拉奇',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '德里',
#    'cx': '1447.84',
#    'cy': '730.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1414', '738.07'],
#      'text': '德里',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '坎普尔',
#    'cx': '1518.84',
#    'cy': '786.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1516', '776.07'],
#      'text': '坎普尔',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '拉萨',
#    'cx': '1726.84',
#    'cy': '718.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1710', '711.07'],
#      'text': '拉萨',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '瓦拉纳西',
#    'cx': '1567.84',
#    'cy': '811.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1536', '831.07'],
#      'text': '瓦拉纳西',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '巴特纳',
#    'cx': '1613.84',
#    'cy': '807.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1621', '814.07'],
#      'text': '巴特纳',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '达卡',
#    'cx': '1736.84',
#    'cy': '861.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1720', '852.07'],
#      'text': '达卡',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '仰光',
#    'cx': '1825.84',
#    'cy': '987.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1811', '980.07'],
#      'text': '仰光',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '曼谷',
#    'cx': '1907.84',
#    'cy': '1046.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1894', '1038.07'],
#      'text': '曼谷',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '归仁',
#    'cx': '2070.84',
#    'cy': '1046.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2035', '1052.07'],
#      'text': '归仁',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '斯里巴加湾',
#    'cx': '2178.84',
#    'cy': '1226.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2159', '1250.07'],
#      'text': '斯里巴加湾',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '棉兰',
#    'cx': '1865.84',
#    'cy': '1251.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1851', '1274.07'],
#      'text': '棉兰',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '新加坡',
#    'cx': '1975.84',
#    'cy': '1296.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1954', '1285.07'],
#      'text': '新加坡',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '巨港',
#    'cx': '1988.84',
#    'cy': '1375.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1974', '1397.07'],
#      'text': '巨港',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '泗水',
#    'cx': '2142.84',
#    'cy': '1459.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2127', '1480.07'],
#      'text': '泗水',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '雅加达',
#    'cx': '2030.84',
#    'cy': '1437.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2009', '1458.07'],
#      'text': '雅加达',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '河内',
#    'cx': '2009.84',
#    'cy': '900.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1972', '907.07'],
#      'text': '河内',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '广州',
#    'cx': '2151.84',
#    'cy': '855.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2136', '848.07'],
#      'text': '广州',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '马尼拉',
#    'cx': '2300.84',
#    'cy': '1031.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2279', '1055.07'],
#      'text': '马尼拉',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '泉州',
#    'cx': '2253.84',
#    'cy': '819.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2231', '811.07'],
#      'text': '泉州',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '福州',
#    'cx': '2268.84',
#    'cy': '794.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['2253', '784.07'],
#      'text': '福州',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '科钦',
#    'cx': '1441.84',
#    'cy': '1121.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1447', '1119.07'],
#      'text': '科钦',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '孟买',
#    'cx': '1380.84',
#    'cy': '939.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1389', '945.07'],
#      'text': '孟买',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '科伦坡',
#    'cx': '1513.84',
#    'cy': '1181.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1497', '1172.07'],
#      'text': '科伦坡',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '白沙瓦',
#    'cx': '1353.84',
#    'cy': '615.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1320', '633.07'],
#      'text': '白沙瓦',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '伊斯兰堡',
#    'cx': '1383.84',
#    'cy': '621.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1393', '626.07'],
#      'text': '伊斯兰堡',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '吉尔吉特',
#    'cx': '1402.84',
#    'cy': '570.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1409', '582.07'],
#      'text': '吉尔吉特',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '皮山',
#    'cx': '1482.84',
#    'cy': '529.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1462', '548.07'],
#      'text': '皮山',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '和田',
#    'cx': '1511.84',
#    'cy': '544.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1503', '537.07'],
#      'text': '和田',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '于阗',
#    'cx': '1542.84',
#    'cy': '552.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1528', '572.07'],
#      'text': '于阗',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '莎车',
#    'cx': '1461.84',
#    'cy': '512.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1466', '509.07'],
#      'text': '莎车',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '撒马尔罕',
#    'cx': '1267.84',
#    'cy': '476.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1259', '492.07'],
#      'text': '撒马尔罕',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '喀什',
#    'cx': '1438.84',
#    'cy': '486.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1396', '493.07'],
#      'text': '喀什',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '巴尔赫',
#    'cx': '1262.84',
#    'cy': '548.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1222', '568.07'],
#      'text': '巴尔赫',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '巴米扬',
#    'cx': '1287.84',
#    'cy': '587.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1233', '593.07'],
#      'text': '巴米扬',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '塔什干',
#    'cx': '1309.84',
#    'cy': '437.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1260', '443.07'],
#      'text': '塔什干',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '阿拉木图',
#    'cx': '1455.84',
#    'cy': '384.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1428', '374.07'],
#      'text': '阿拉木图',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '温宿',
#    'cx': '1521.84',
#    'cy': '442.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1503', '434.07'],
#      'text': '温宿',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '库车',
#    'cx': '1571.84',
#    'cy': '428.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1555', '449.07'],
#      'text': '库车',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '焉耆',
#    'cx': '1648.84',
#    'cy': '422.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1613', '419.07'],
#      'text': '焉耆',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '高昌',
#    'cx': '1695.84',
#    'cy': '405.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1668', '397.07'],
#      'text': '高昌',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '北庭',
#    'cx': '1691.84',
#    'cy': '362.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1678', '354.07'],
#      'text': '北庭',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '楼兰',
#    'cx': '1701.84',
#    'cy': '458.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1662', '466.07'],
#      'text': '楼兰',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '比什凯克',
#    'cx': '1411.84',
#    'cy': '395.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1355', '388.07'],
#      'text': '比什凯克',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '塔拉兹',
#    'cx': '1345.84',
#    'cy': '400.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1332', '419.07'],
#      'text': '塔拉兹',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '西姆肯特',
#    'cx': '1315.84',
#    'cy': '410.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1247', '415.07'],
#      'text': '西姆肯特',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '喀布尔',
#    'cx': '1309.84',
#    'cy': '603.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1255', '614.07'],
#      'text': '喀布尔',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '坎大哈',
#    'cx': '1245.91',
#    'cy': '673.489',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1201', '664.862'],
#      'text': '坎大哈',
#      'font-size': '14.9847',
#      'transform': ''}]},
#   {'id': '摩加迪沙',
#    'cx': '854.843',
#    'cy': '1275.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['821', '1266.07'],
#      'text': '摩加迪沙',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '达累斯萨拉姆',
#    'cx': '738.843',
#    'cy': '1448.84',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['681', '1469.07'],
#      'text': '达累斯萨拉姆',
#      'font-size': '15.3176',
#      'transform': ''}]},
#   {'id': '巴格达',
#    'cx': '836.843',
#    'cy': '632.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['841', '637.13'],
#      'text': '巴格达',
#      'font-size': '15.4824',
#      'transform': ''}]},
#   {'id': '伊斯法罕',
#    'cx': '976.375',
#    'cy': '647.895',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['906', '659.539'],
#      'text': '伊斯法罕',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '巴士拉',
#    'cx': '901.843',
#    'cy': '696.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['852', '710.48'],
#      'text': '巴士拉',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '未知1',
#    'cx': '1062.45',
#    'cy': '821.589',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1032', '843.48'],
#      'text': '未知1',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '未知2',
#    'cx': '1108.84',
#    'cy': '846.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1086', '874.48'],
#      'text': '未知2',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '伯斯波利斯',
#    'cx': '1000.97',
#    'cy': '707.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1005', '721.48'],
#      'text': '伯斯波利斯',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '亚兹德',
#    'cx': '1024.56',
#    'cy': '663.803',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1017', '657.48'],
#      'text': '亚兹德',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '克尔曼',
#    'cx': '1076.29',
#    'cy': '700.157',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1077', '692.48'],
#      'text': '克尔曼',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '巴姆',
#    'cx': '1099.34',
#    'cy': '724.751',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1099', '717.48'],
#      'text': '巴姆',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '扎黑丹',
#    'cx': '1151.84',
#    'cy': '718.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1135', '741.48'],
#      'text': '扎黑丹',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '霍尔木兹',
#    'cx': '1065.53',
#    'cy': '765.716',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1073', '771.48'],
#      'text': '霍尔木兹',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '德黑兰',
#    'cx': '971.764',
#    'cy': '576.651',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['952', '597.48'],
#      'text': '德黑兰',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '摩苏尔',
#    'cx': '812.843',
#    'cy': '560.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['791', '553.48'],
#      'text': '摩苏尔',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '马什哈德',
#    'cx': '1129.09',
#    'cy': '563.354',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1111', '585.48'],
#      'text': '马什哈德',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '梅尔夫',
#    'cx': '1176.2',
#    'cy': '531.074',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1162', '556.48'],
#      'text': '梅尔夫',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '布哈拉',
#    'cx': '1224.39',
#    'cy': '476.738',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['1171', '480.176'],
#      'text': '布哈拉',
#      'font-size': '15.6077',
#      'transform': ''}]},
#   {'id': '加兹温',
#    'cx': '955.856',
#    'cy': '568.965',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['899', '574.48'],
#      'text': '加兹温',
#      'font-size': '15.0706',
#      'transform': ''}]},
#   {'id': '威尼斯',
#    'cx': '220.843',
#    'cy': '326.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['163', '327.109'],
#      'text': '威尼斯',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '布达佩斯',
#    'cx': '351.843',
#    'cy': '268.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['335', '261.109'],
#      'text': '布达佩斯',
#      'font-size': '16.8',
#      'transform': ''}]},
#   {'id': '罗马',
#    'cx': '226.843',
#    'cy': '422.843',
#    'r': '3.84279',
#    'fill': 'black',
#    'tag': 'circle',
#    'text': [{'pos': ['209', '443.109'],
#      'text': '罗马',
#      'font-size': '16.8',
#      'transform': ''}]}]}

# %% [markdown]
# ##### 保存结果

# %%
import json
with open("./silk.json", "w", encoding="utf-8") as f:
    f.write(json.dumps(layers, ensure_ascii=False))
